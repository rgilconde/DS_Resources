# %% [markdown]
# # Import Dependencies

# %%
# import global dependencies
import pandas as pd
import os
import glob
import numpy as np
# import src dependencies
os.chdir("../..")
from  src.anomaly_detection.Autoencoder_anomaly_detection import *
# Volvemos a test
os.chdir("test/Autoencoder_Anomaly_detection")

# %% [markdown]
# # Autoencoder Anomaly Detection

# %%
# ETL
data=pd.read_csv("autoencoder.csv").dropna()

# Select variables & data train & data new
porcentaje_train=0.8
features=['Open','High','Low','Close', 'Volume', 'Close Time',
       'Quote asset volume', 'Number of trades', 'Taker buy base asset volume',
       'Taker buy quote asset volume']
direccion='models/'

data_select_dataframe=data.iloc[:int(data.shape[0]*porcentaje_train),:]
data_select=np.array(data.loc[:,features].iloc[:int(data.shape[0]*porcentaje_train),:])
data_select_new=np.array(data.loc[:,features].iloc[int(data.shape[0]*porcentaje_train):,:])
data_select_new_dataframe=data.iloc[int(data.shape[0]*porcentaje_train):,:]

# Scaler
data_select=Scaler(df=data_select,direction=direccion)

# %%
# Create model
data_array=data_select
# model
dim_1=128
dim_2=64
dim_3=32
dp=0.2
patience=100


model=model_autoencoder(data=data_array,dim_1=dim_1,dim_2=dim_2,dim_3=dim_3,dp=dp)

# Training
direccion='models/'
bs=int(data_array.shape[0]/500)
n_epochs=100000
verbose=1

training(data=data_array,model=model,patience=patience,direccion=direccion,bs=bs,n_epochs=n_epochs,verbose=verbose)

# P_value
porcentaje_max=0.01
direction='results/'
resta_global_total=P_value_calculate(model_dir='models/model_autoencoder.h5',data_array=data_array,porcentaje_max=porcentaje_max,direction=direction)

# # Results
direction='results/'
value_limited=np.load(direction+'p_value.npy')
direction='results/'
result=Export_results_xlsx(resta_global_total=resta_global_total,value_limited=value_limited,data_select_dataframe=data_select_dataframe,direccion=direction)


# Graphs
direction='results/graph'
graphs(direccion=direction,result=result)
# Out:
# 2022-01-27 09:54:07.833556: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-01-27 09:54:07.833597: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-01-27 09:54:07.833630: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (rgil-ThinkPad-E580): /proc/driver/nvidia/version does not exist
# 2022-01-27 09:54:07.833975: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-01-27 09:54:07.993982: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100000
# 501/501 [==============================] - 2s 2ms/step - loss: 0.1835
#
# Epoch 00001: loss improved from inf to 0.18353, saving model to models/model_autoencoder.h5
# Epoch 2/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0158
#
# Epoch 00002: loss improved from 0.18353 to 0.01579, saving model to models/model_autoencoder.h5
# Epoch 3/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0072
#
# Epoch 00003: loss improved from 0.01579 to 0.00725, saving model to models/model_autoencoder.h5
# Epoch 4/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0047
#
# Epoch 00004: loss improved from 0.00725 to 0.00474, saving model to models/model_autoencoder.h5
# Epoch 5/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0026
#
# Epoch 00005: loss improved from 0.00474 to 0.00262, saving model to models/model_autoencoder.h5
# Epoch 6/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0016
#
# Epoch 00006: loss improved from 0.00262 to 0.00164, saving model to models/model_autoencoder.h5
# Epoch 7/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0013
#
# Epoch 00007: loss improved from 0.00164 to 0.00130, saving model to models/model_autoencoder.h5
# Epoch 8/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0010
#
# Epoch 00008: loss improved from 0.00130 to 0.00101, saving model to models/model_autoencoder.h5
# Epoch 9/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 0.0011
#
# Epoch 00009: loss did not improve from 0.00101
# Epoch 10/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.2653e-04
#
# Epoch 00010: loss improved from 0.00101 to 0.00073, saving model to models/model_autoencoder.h5
# Epoch 11/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.8653e-04
#
# Epoch 00011: loss improved from 0.00073 to 0.00069, saving model to models/model_autoencoder.h5
# Epoch 12/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.0522e-04
#
# Epoch 00012: loss improved from 0.00069 to 0.00061, saving model to models/model_autoencoder.h5
# Epoch 13/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.0777e-04
#
# Epoch 00013: loss did not improve from 0.00061
# Epoch 14/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.2435e-04
#
# Epoch 00014: loss improved from 0.00061 to 0.00052, saving model to models/model_autoencoder.h5
# Epoch 15/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.2435e-04
#
# Epoch 00015: loss improved from 0.00052 to 0.00052, saving model to models/model_autoencoder.h5
# Epoch 16/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.2157e-04
#
# Epoch 00016: loss did not improve from 0.00052
# Epoch 17/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.1280e-04
#
# Epoch 00017: loss improved from 0.00052 to 0.00041, saving model to models/model_autoencoder.h5
# Epoch 18/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8919e-04
#
# Epoch 00018: loss improved from 0.00041 to 0.00039, saving model to models/model_autoencoder.h5
# Epoch 19/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0039e-04
#
# Epoch 00019: loss did not improve from 0.00039
# Epoch 20/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7661e-04
#
# Epoch 00020: loss improved from 0.00039 to 0.00038, saving model to models/model_autoencoder.h5
# Epoch 21/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 3.4908e-04
#
# Epoch 00021: loss improved from 0.00038 to 0.00035, saving model to models/model_autoencoder.h5
# Epoch 22/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 3.4352e-04
#
# Epoch 00022: loss improved from 0.00035 to 0.00034, saving model to models/model_autoencoder.h5
# Epoch 23/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 3.5017e-04
#
# Epoch 00023: loss did not improve from 0.00034
# Epoch 24/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 2.9893e-04
#
# Epoch 00024: loss improved from 0.00034 to 0.00030, saving model to models/model_autoencoder.h5
# Epoch 25/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.0617e-04
#
# Epoch 00025: loss did not improve from 0.00030
# Epoch 26/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.9941e-04
#
# Epoch 00026: loss did not improve from 0.00030
# Epoch 27/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.2749e-04
#
# Epoch 00027: loss did not improve from 0.00030
# Epoch 28/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.7377e-04
#
# Epoch 00028: loss improved from 0.00030 to 0.00027, saving model to models/model_autoencoder.h5
# Epoch 29/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.5941e-04
#
# Epoch 00029: loss improved from 0.00027 to 0.00026, saving model to models/model_autoencoder.h5
# Epoch 30/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.6295e-04
#
# Epoch 00030: loss did not improve from 0.00026
# Epoch 31/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.7502e-04
#
# Epoch 00031: loss did not improve from 0.00026
# Epoch 32/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.4873e-04
#
# Epoch 00032: loss improved from 0.00026 to 0.00025, saving model to models/model_autoencoder.h5
# Epoch 33/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7315e-04
#
# Epoch 00033: loss did not improve from 0.00025
# Epoch 34/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0854e-04
#
# Epoch 00034: loss improved from 0.00025 to 0.00021, saving model to models/model_autoencoder.h5
# Epoch 35/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1407e-04
#
# Epoch 00035: loss did not improve from 0.00021
# Epoch 36/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.2602e-04
#
# Epoch 00036: loss did not improve from 0.00021
# Epoch 37/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.9490e-04
#
# Epoch 00037: loss did not improve from 0.00021
# Epoch 38/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0205e-04
#
# Epoch 00038: loss improved from 0.00021 to 0.00020, saving model to models/model_autoencoder.h5
# Epoch 39/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0420e-04
#
# Epoch 00039: loss did not improve from 0.00020
# Epoch 40/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.2017e-04
#
# Epoch 00040: loss did not improve from 0.00020
# Epoch 41/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1921e-04
#
# Epoch 00041: loss did not improve from 0.00020
# Epoch 42/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.2094e-04
#
# Epoch 00042: loss did not improve from 0.00020
# Epoch 43/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.3194e-04
#
# Epoch 00043: loss did not improve from 0.00020
# Epoch 44/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1738e-04
#
# Epoch 00044: loss did not improve from 0.00020
# Epoch 45/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.1765e-04
#
# Epoch 00045: loss did not improve from 0.00020
# Epoch 46/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9166e-04
#
# Epoch 00046: loss improved from 0.00020 to 0.00019, saving model to models/model_autoencoder.h5
# Epoch 47/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.0033e-04
#
# Epoch 00047: loss did not improve from 0.00019
# Epoch 48/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8257e-04
#
# Epoch 00048: loss improved from 0.00019 to 0.00018, saving model to models/model_autoencoder.h5
# Epoch 49/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.3724e-04
#
# Epoch 00049: loss did not improve from 0.00018
# Epoch 50/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8634e-04
#
# Epoch 00050: loss did not improve from 0.00018
# Epoch 51/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7405e-04
#
# Epoch 00051: loss improved from 0.00018 to 0.00017, saving model to models/model_autoencoder.h5
# Epoch 52/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9841e-04
#
# Epoch 00052: loss did not improve from 0.00017
# Epoch 53/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7206e-04
#
# Epoch 00053: loss improved from 0.00017 to 0.00017, saving model to models/model_autoencoder.h5
# Epoch 54/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9994e-04
#
# Epoch 00054: loss did not improve from 0.00017
# Epoch 55/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.9204e-04
#
# Epoch 00055: loss did not improve from 0.00017
# Epoch 56/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7217e-04
#
# Epoch 00056: loss did not improve from 0.00017
# Epoch 57/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8607e-04
#
# Epoch 00057: loss did not improve from 0.00017
# Epoch 58/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7435e-04
#
# Epoch 00058: loss did not improve from 0.00017
# Epoch 59/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5938e-04
#
# Epoch 00059: loss improved from 0.00017 to 0.00016, saving model to models/model_autoencoder.h5
# Epoch 60/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 2.6338e-04
#
# Epoch 00060: loss did not improve from 0.00016
# Epoch 61/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4827e-04
#
# Epoch 00061: loss improved from 0.00016 to 0.00015, saving model to models/model_autoencoder.h5
# Epoch 62/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5642e-04
#
# Epoch 00062: loss did not improve from 0.00015
# Epoch 63/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7437e-04
#
# Epoch 00063: loss did not improve from 0.00015
# Epoch 64/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8528e-04
#
# Epoch 00064: loss did not improve from 0.00015
# Epoch 65/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4910e-04
#
# Epoch 00065: loss did not improve from 0.00015
# Epoch 66/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6111e-04
#
# Epoch 00066: loss did not improve from 0.00015
# Epoch 67/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7549e-04
#
# Epoch 00067: loss did not improve from 0.00015
# Epoch 68/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5178e-04
#
# Epoch 00068: loss did not improve from 0.00015
# Epoch 69/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.7407e-04
#
# Epoch 00069: loss did not improve from 0.00015
# Epoch 70/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5235e-04
#
# Epoch 00070: loss did not improve from 0.00015
# Epoch 71/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5281e-04
#
# Epoch 00071: loss did not improve from 0.00015
# Epoch 72/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.8199e-04
#
# Epoch 00072: loss did not improve from 0.00015
# Epoch 73/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4134e-04
#
# Epoch 00073: loss improved from 0.00015 to 0.00014, saving model to models/model_autoencoder.h5
# Epoch 74/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5760e-04
#
# Epoch 00074: loss did not improve from 0.00014
# Epoch 75/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5095e-04
#
# Epoch 00075: loss did not improve from 0.00014
# Epoch 76/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5398e-04
#
# Epoch 00076: loss did not improve from 0.00014
# Epoch 77/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4528e-04
#
# Epoch 00077: loss did not improve from 0.00014
# Epoch 78/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5990e-04
#
# Epoch 00078: loss did not improve from 0.00014
# Epoch 79/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5792e-04
#
# Epoch 00079: loss did not improve from 0.00014
# Epoch 80/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6061e-04
#
# Epoch 00080: loss did not improve from 0.00014
# Epoch 81/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2833e-04
#
# Epoch 00081: loss improved from 0.00014 to 0.00013, saving model to models/model_autoencoder.h5
# Epoch 82/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4551e-04
#
# Epoch 00082: loss did not improve from 0.00013
# Epoch 83/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.6821e-04
#
# Epoch 00083: loss did not improve from 0.00013
# Epoch 84/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3903e-04
#
# Epoch 00084: loss did not improve from 0.00013
# Epoch 85/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4798e-04
#
# Epoch 00085: loss did not improve from 0.00013
# Epoch 86/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3975e-04
#
# Epoch 00086: loss did not improve from 0.00013
# Epoch 87/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4058e-04
#
# Epoch 00087: loss did not improve from 0.00013
# Epoch 88/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4984e-04
#
# Epoch 00088: loss did not improve from 0.00013
# Epoch 89/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5755e-04
#
# Epoch 00089: loss did not improve from 0.00013
# Epoch 90/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4283e-04
#
# Epoch 00090: loss did not improve from 0.00013
# Epoch 91/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2930e-04
#
# Epoch 00091: loss did not improve from 0.00013
# Epoch 92/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3196e-04
#
# Epoch 00092: loss did not improve from 0.00013
# Epoch 93/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3397e-04
#
# Epoch 00093: loss did not improve from 0.00013
# Epoch 94/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3264e-04
#
# Epoch 00094: loss did not improve from 0.00013
# Epoch 95/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3366e-04
#
# Epoch 00095: loss did not improve from 0.00013
# Epoch 96/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3960e-04
#
# Epoch 00096: loss did not improve from 0.00013
# Epoch 97/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3803e-04
#
# Epoch 00097: loss did not improve from 0.00013
# Epoch 98/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3213e-04
#
# Epoch 00098: loss did not improve from 0.00013
# Epoch 99/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3587e-04
#
# Epoch 00099: loss did not improve from 0.00013
# Epoch 100/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1804e-04
#
# Epoch 00100: loss improved from 0.00013 to 0.00012, saving model to models/model_autoencoder.h5
# Epoch 101/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4582e-04
#
# Epoch 00101: loss did not improve from 0.00012
# Epoch 102/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4984e-04
#
# Epoch 00102: loss did not improve from 0.00012
# Epoch 103/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2000e-04
#
# Epoch 00103: loss did not improve from 0.00012
# Epoch 104/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2936e-04
#
# Epoch 00104: loss did not improve from 0.00012
# Epoch 105/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3027e-04
#
# Epoch 00105: loss did not improve from 0.00012
# Epoch 106/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1796e-04
#
# Epoch 00106: loss improved from 0.00012 to 0.00012, saving model to models/model_autoencoder.h5
# Epoch 107/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2275e-04
#
# Epoch 00107: loss did not improve from 0.00012
# Epoch 108/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1814e-04
#
# Epoch 00108: loss did not improve from 0.00012
# Epoch 109/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2610e-04
#
# Epoch 00109: loss did not improve from 0.00012
# Epoch 110/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1927e-04
#
# Epoch 00110: loss did not improve from 0.00012
# Epoch 111/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2843e-04
#
# Epoch 00111: loss did not improve from 0.00012
# Epoch 112/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1973e-04
#
# Epoch 00112: loss did not improve from 0.00012
# Epoch 113/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2746e-04
#
# Epoch 00113: loss did not improve from 0.00012
# Epoch 114/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2098e-04
#
# Epoch 00114: loss did not improve from 0.00012
# Epoch 115/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2345e-04
#
# Epoch 00115: loss did not improve from 0.00012
# Epoch 116/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2201e-04
#
# Epoch 00116: loss did not improve from 0.00012
# Epoch 117/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1152e-04
#
# Epoch 00117: loss improved from 0.00012 to 0.00011, saving model to models/model_autoencoder.h5
# Epoch 118/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.3616e-04
#
# Epoch 00118: loss did not improve from 0.00011
# Epoch 119/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1603e-04
#
# Epoch 00119: loss did not improve from 0.00011
# Epoch 120/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0808e-04
#
# Epoch 00120: loss improved from 0.00011 to 0.00011, saving model to models/model_autoencoder.h5
# Epoch 121/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1978e-04
#
# Epoch 00121: loss did not improve from 0.00011
# Epoch 122/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0681e-04
#
# Epoch 00122: loss improved from 0.00011 to 0.00011, saving model to models/model_autoencoder.h5
# Epoch 123/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0650e-04
#
# Epoch 00123: loss improved from 0.00011 to 0.00011, saving model to models/model_autoencoder.h5
# Epoch 124/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4143e-04
#
# Epoch 00124: loss did not improve from 0.00011
# Epoch 125/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0970e-04
#
# Epoch 00125: loss did not improve from 0.00011
# Epoch 126/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4034e-04
#
# Epoch 00126: loss did not improve from 0.00011
# Epoch 127/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0649e-04
#
# Epoch 00127: loss improved from 0.00011 to 0.00011, saving model to models/model_autoencoder.h5
# Epoch 128/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1111e-04
#
# Epoch 00128: loss did not improve from 0.00011
# Epoch 129/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1211e-04
#
# Epoch 00129: loss did not improve from 0.00011
# Epoch 130/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1085e-04
#
# Epoch 00130: loss did not improve from 0.00011
# Epoch 131/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.4432e-04
#
# Epoch 00131: loss did not improve from 0.00011
# Epoch 132/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0299e-04
#
# Epoch 00132: loss improved from 0.00011 to 0.00010, saving model to models/model_autoencoder.h5
# Epoch 133/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2292e-04
#
# Epoch 00133: loss did not improve from 0.00010
# Epoch 134/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0933e-04
#
# Epoch 00134: loss did not improve from 0.00010
# Epoch 135/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2956e-04
#
# Epoch 00135: loss did not improve from 0.00010
# Epoch 136/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0641e-04
#
# Epoch 00136: loss did not improve from 0.00010
# Epoch 137/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0320e-04
#
# Epoch 00137: loss did not improve from 0.00010
# Epoch 138/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1067e-04
#
# Epoch 00138: loss did not improve from 0.00010
# Epoch 139/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0413e-04
#
# Epoch 00139: loss did not improve from 0.00010
# Epoch 140/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1727e-04
#
# Epoch 00140: loss did not improve from 0.00010
# Epoch 141/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.8641e-05
#
# Epoch 00141: loss improved from 0.00010 to 0.00010, saving model to models/model_autoencoder.h5
# Epoch 142/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1928e-04
#
# Epoch 00142: loss did not improve from 0.00010
# Epoch 143/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1259e-04
#
# Epoch 00143: loss did not improve from 0.00010
# Epoch 144/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0957e-04
#
# Epoch 00144: loss did not improve from 0.00010
# Epoch 145/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1168e-04
#
# Epoch 00145: loss did not improve from 0.00010
# Epoch 146/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0846e-04
#
# Epoch 00146: loss did not improve from 0.00010
# Epoch 147/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1174e-04
#
# Epoch 00147: loss did not improve from 0.00010
# Epoch 148/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0443e-04
#
# Epoch 00148: loss did not improve from 0.00010
# Epoch 149/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0492e-04
#
# Epoch 00149: loss did not improve from 0.00010
# Epoch 150/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.9303e-05
#
# Epoch 00150: loss did not improve from 0.00010
# Epoch 151/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0590e-04
#
# Epoch 00151: loss did not improve from 0.00010
# Epoch 152/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1121e-04
#
# Epoch 00152: loss did not improve from 0.00010
# Epoch 153/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0574e-04
#
# Epoch 00153: loss did not improve from 0.00010
# Epoch 154/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1631e-04
#
# Epoch 00154: loss did not improve from 0.00010
# Epoch 155/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0777e-04
#
# Epoch 00155: loss did not improve from 0.00010
# Epoch 156/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0630e-04
#
# Epoch 00156: loss did not improve from 0.00010
# Epoch 157/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.9285e-05
#
# Epoch 00157: loss did not improve from 0.00010
# Epoch 158/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1690e-04
#
# Epoch 00158: loss did not improve from 0.00010
# Epoch 159/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0607e-04
#
# Epoch 00159: loss did not improve from 0.00010
# Epoch 160/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0008e-04
#
# Epoch 00160: loss did not improve from 0.00010
# Epoch 161/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2157e-04
#
# Epoch 00161: loss did not improve from 0.00010
# Epoch 162/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0297e-04
#
# Epoch 00162: loss did not improve from 0.00010
# Epoch 163/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0235e-04
#
# Epoch 00163: loss did not improve from 0.00010
# Epoch 164/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0371e-04
#
# Epoch 00164: loss did not improve from 0.00010
# Epoch 165/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1340e-04
#
# Epoch 00165: loss did not improve from 0.00010
# Epoch 166/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.0702e-05
#
# Epoch 00166: loss improved from 0.00010 to 0.00009, saving model to models/model_autoencoder.h5
# Epoch 167/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.5080e-04
#
# Epoch 00167: loss did not improve from 0.00009
# Epoch 168/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3573e-05
#
# Epoch 00168: loss did not improve from 0.00009
# Epoch 169/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0240e-04
#
# Epoch 00169: loss did not improve from 0.00009
# Epoch 170/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.8919e-05
#
# Epoch 00170: loss did not improve from 0.00009
# Epoch 171/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0707e-04
#
# Epoch 00171: loss did not improve from 0.00009
# Epoch 172/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0870e-04
#
# Epoch 00172: loss did not improve from 0.00009
# Epoch 173/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 1.0397e-04
#
# Epoch 00173: loss did not improve from 0.00009
# Epoch 174/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0700e-04
#
# Epoch 00174: loss did not improve from 0.00009
# Epoch 175/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0111e-04
#
# Epoch 00175: loss did not improve from 0.00009
# Epoch 176/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3510e-05
#
# Epoch 00176: loss did not improve from 0.00009
# Epoch 177/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3960e-05
#
# Epoch 00177: loss did not improve from 0.00009
# Epoch 178/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0728e-04
#
# Epoch 00178: loss did not improve from 0.00009
# Epoch 179/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0204e-04
#
# Epoch 00179: loss did not improve from 0.00009
# Epoch 180/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 1.0485e-04
#
# Epoch 00180: loss did not improve from 0.00009
# Epoch 181/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1193e-04
#
# Epoch 00181: loss did not improve from 0.00009
# Epoch 182/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 9.3014e-05
#
# Epoch 00182: loss did not improve from 0.00009
# Epoch 183/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.6339e-05
#
# Epoch 00183: loss did not improve from 0.00009
# Epoch 184/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0124e-04
#
# Epoch 00184: loss did not improve from 0.00009
# Epoch 185/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 9.6919e-05
#
# Epoch 00185: loss did not improve from 0.00009
# Epoch 186/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.1978e-05
#
# Epoch 00186: loss did not improve from 0.00009
# Epoch 187/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1834e-04
#
# Epoch 00187: loss did not improve from 0.00009
# Epoch 188/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8129e-05
#
# Epoch 00188: loss improved from 0.00009 to 0.00009, saving model to models/model_autoencoder.h5
# Epoch 189/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.1483e-05
#
# Epoch 00189: loss did not improve from 0.00009
# Epoch 190/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.7224e-05
#
# Epoch 00190: loss did not improve from 0.00009
# Epoch 191/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0077e-04
#
# Epoch 00191: loss did not improve from 0.00009
# Epoch 192/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.3033e-05
#
# Epoch 00192: loss improved from 0.00009 to 0.00008, saving model to models/model_autoencoder.h5
# Epoch 193/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0463e-04
#
# Epoch 00193: loss did not improve from 0.00008
# Epoch 194/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.8452e-05
#
# Epoch 00194: loss did not improve from 0.00008
# Epoch 195/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0264e-04
#
# Epoch 00195: loss did not improve from 0.00008
# Epoch 196/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1002e-04
#
# Epoch 00196: loss did not improve from 0.00008
# Epoch 197/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8326e-05
#
# Epoch 00197: loss did not improve from 0.00008
# Epoch 198/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.2965e-05
#
# Epoch 00198: loss did not improve from 0.00008
# Epoch 199/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1176e-04
#
# Epoch 00199: loss did not improve from 0.00008
# Epoch 200/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1063e-04
#
# Epoch 00200: loss did not improve from 0.00008
# Epoch 201/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8680e-05
#
# Epoch 00201: loss did not improve from 0.00008
# Epoch 202/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.0806e-05
#
# Epoch 00202: loss did not improve from 0.00008
# Epoch 203/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.6654e-05
#
# Epoch 00203: loss did not improve from 0.00008
# Epoch 204/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.9479e-05
#
# Epoch 00204: loss did not improve from 0.00008
# Epoch 205/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0931e-04
#
# Epoch 00205: loss did not improve from 0.00008
# Epoch 206/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4292e-05
#
# Epoch 00206: loss did not improve from 0.00008
# Epoch 207/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3428e-05
#
# Epoch 00207: loss did not improve from 0.00008
# Epoch 208/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9334e-05
#
# Epoch 00208: loss improved from 0.00008 to 0.00008, saving model to models/model_autoencoder.h5
# Epoch 209/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0822e-04
#
# Epoch 00209: loss did not improve from 0.00008
# Epoch 210/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0127e-04
#
# Epoch 00210: loss did not improve from 0.00008
# Epoch 211/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4869e-05
#
# Epoch 00211: loss did not improve from 0.00008
# Epoch 212/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.5521e-05
#
# Epoch 00212: loss did not improve from 0.00008
# Epoch 213/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0662e-04
#
# Epoch 00213: loss did not improve from 0.00008
# Epoch 214/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.5544e-05
#
# Epoch 00214: loss did not improve from 0.00008
# Epoch 215/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1696e-04
#
# Epoch 00215: loss did not improve from 0.00008
# Epoch 216/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9201e-05
#
# Epoch 00216: loss improved from 0.00008 to 0.00008, saving model to models/model_autoencoder.h5
# Epoch 217/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.0241e-05
#
# Epoch 00217: loss did not improve from 0.00008
# Epoch 218/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4956e-05
#
# Epoch 00218: loss did not improve from 0.00008
# Epoch 219/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8617e-05
#
# Epoch 00219: loss did not improve from 0.00008
# Epoch 220/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.7057e-05
#
# Epoch 00220: loss did not improve from 0.00008
# Epoch 221/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.6459e-05
#
# Epoch 00221: loss did not improve from 0.00008
# Epoch 222/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.2008e-05
#
# Epoch 00222: loss did not improve from 0.00008
# Epoch 223/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4854e-05
#
# Epoch 00223: loss did not improve from 0.00008
# Epoch 224/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.9222e-05
#
# Epoch 00224: loss did not improve from 0.00008
# Epoch 225/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4119e-05
#
# Epoch 00225: loss did not improve from 0.00008
# Epoch 226/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.2115e-05
#
# Epoch 00226: loss did not improve from 0.00008
# Epoch 227/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.9134e-05
#
# Epoch 00227: loss did not improve from 0.00008
# Epoch 228/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7383e-05
#
# Epoch 00228: loss did not improve from 0.00008
# Epoch 229/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.2431e-05
#
# Epoch 00229: loss did not improve from 0.00008
# Epoch 230/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.5914e-05
#
# Epoch 00230: loss did not improve from 0.00008
# Epoch 231/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.4991e-05
#
# Epoch 00231: loss improved from 0.00008 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 232/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0110e-04
#
# Epoch 00232: loss did not improve from 0.00007
# Epoch 233/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7452e-05
#
# Epoch 00233: loss did not improve from 0.00007
# Epoch 234/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4814e-05
#
# Epoch 00234: loss did not improve from 0.00007
# Epoch 235/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.5438e-05
#
# Epoch 00235: loss did not improve from 0.00007
# Epoch 236/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.5263e-05
#
# Epoch 00236: loss did not improve from 0.00007
# Epoch 237/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.8342e-05
#
# Epoch 00237: loss did not improve from 0.00007
# Epoch 238/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7039e-05
#
# Epoch 00238: loss did not improve from 0.00007
# Epoch 239/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4307e-05
#
# Epoch 00239: loss did not improve from 0.00007
# Epoch 240/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0612e-04
#
# Epoch 00240: loss did not improve from 0.00007
# Epoch 241/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.2282e-05
#
# Epoch 00241: loss did not improve from 0.00007
# Epoch 242/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4251e-05
#
# Epoch 00242: loss did not improve from 0.00007
# Epoch 243/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3098e-05
#
# Epoch 00243: loss did not improve from 0.00007
# Epoch 244/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.4743e-05
#
# Epoch 00244: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 245/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.2843e-05
#
# Epoch 00245: loss did not improve from 0.00007
# Epoch 246/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.3876e-05
#
# Epoch 00246: loss did not improve from 0.00007
# Epoch 247/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.9033e-05
#
# Epoch 00247: loss did not improve from 0.00007
# Epoch 248/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.6523e-05
#
# Epoch 00248: loss did not improve from 0.00007
# Epoch 249/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.1080e-05
#
# Epoch 00249: loss did not improve from 0.00007
# Epoch 250/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7256e-05
#
# Epoch 00250: loss did not improve from 0.00007
# Epoch 251/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9765e-05
#
# Epoch 00251: loss did not improve from 0.00007
# Epoch 252/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8234e-05
#
# Epoch 00252: loss did not improve from 0.00007
# Epoch 253/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4474e-05
#
# Epoch 00253: loss did not improve from 0.00007
# Epoch 254/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8092e-05
#
# Epoch 00254: loss did not improve from 0.00007
# Epoch 255/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4198e-05
#
# Epoch 00255: loss did not improve from 0.00007
# Epoch 256/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.3444e-05
#
# Epoch 00256: loss did not improve from 0.00007
# Epoch 257/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.3120e-05
#
# Epoch 00257: loss did not improve from 0.00007
# Epoch 258/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.8152e-05
#
# Epoch 00258: loss did not improve from 0.00007
# Epoch 259/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.6512e-05
#
# Epoch 00259: loss did not improve from 0.00007
# Epoch 260/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.3927e-05
#
# Epoch 00260: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 261/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0114e-04
#
# Epoch 00261: loss did not improve from 0.00007
# Epoch 262/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.5540e-05
#
# Epoch 00262: loss did not improve from 0.00007
# Epoch 263/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.9070e-05
#
# Epoch 00263: loss did not improve from 0.00007
# Epoch 264/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.1727e-05
#
# Epoch 00264: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 265/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7418e-05
#
# Epoch 00265: loss did not improve from 0.00007
# Epoch 266/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.3428e-05
#
# Epoch 00266: loss did not improve from 0.00007
# Epoch 267/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.7216e-05
#
# Epoch 00267: loss did not improve from 0.00007
# Epoch 268/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.7785e-05
#
# Epoch 00268: loss did not improve from 0.00007
# Epoch 269/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8932e-05
#
# Epoch 00269: loss did not improve from 0.00007
# Epoch 270/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.7762e-05
#
# Epoch 00270: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 271/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.2637e-04
#
# Epoch 00271: loss did not improve from 0.00007
# Epoch 272/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.2407e-05
#
# Epoch 00272: loss did not improve from 0.00007
# Epoch 273/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.2031e-05
#
# Epoch 00273: loss did not improve from 0.00007
# Epoch 274/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4934e-05
#
# Epoch 00274: loss did not improve from 0.00007
# Epoch 275/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9843e-05
#
# Epoch 00275: loss did not improve from 0.00007
# Epoch 276/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.1069e-05
#
# Epoch 00276: loss did not improve from 0.00007
# Epoch 277/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7006e-05
#
# Epoch 00277: loss did not improve from 0.00007
# Epoch 278/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.4486e-05
#
# Epoch 00278: loss did not improve from 0.00007
# Epoch 279/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4069e-05
#
# Epoch 00279: loss did not improve from 0.00007
# Epoch 280/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9007e-05
#
# Epoch 00280: loss did not improve from 0.00007
# Epoch 281/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.9143e-05
#
# Epoch 00281: loss did not improve from 0.00007
# Epoch 282/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.1358e-05
#
# Epoch 00282: loss did not improve from 0.00007
# Epoch 283/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.8860e-05
#
# Epoch 00283: loss did not improve from 0.00007
# Epoch 284/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.4488e-05
#
# Epoch 00284: loss did not improve from 0.00007
# Epoch 285/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.1512e-05
#
# Epoch 00285: loss did not improve from 0.00007
# Epoch 286/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0118e-04
#
# Epoch 00286: loss did not improve from 0.00007
# Epoch 287/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.6938e-05
#
# Epoch 00287: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 288/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.9376e-05
#
# Epoch 00288: loss did not improve from 0.00007
# Epoch 289/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.7779e-05
#
# Epoch 00289: loss did not improve from 0.00007
# Epoch 290/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0585e-04
#
# Epoch 00290: loss did not improve from 0.00007
# Epoch 291/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.4378e-05
#
# Epoch 00291: loss did not improve from 0.00007
# Epoch 292/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.6619e-05
#
# Epoch 00292: loss improved from 0.00007 to 0.00007, saving model to models/model_autoencoder.h5
# Epoch 293/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9092e-05
#
# Epoch 00293: loss did not improve from 0.00007
# Epoch 294/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.2535e-05
#
# Epoch 00294: loss did not improve from 0.00007
# Epoch 295/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.0127e-05
#
# Epoch 00295: loss did not improve from 0.00007
# Epoch 296/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.1237e-05
#
# Epoch 00296: loss did not improve from 0.00007
# Epoch 297/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.5337e-05
#
# Epoch 00297: loss did not improve from 0.00007
# Epoch 298/100000
# 501/501 [==============================] - 1s 3ms/step - loss: 7.8521e-05
#
# Epoch 00298: loss did not improve from 0.00007
# Epoch 299/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.1126e-04
#
# Epoch 00299: loss did not improve from 0.00007
# Epoch 300/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.3268e-05
#
# Epoch 00300: loss improved from 0.00007 to 0.00006, saving model to models/model_autoencoder.h5
# Epoch 301/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.0332e-05
#
# Epoch 00301: loss did not improve from 0.00006
# Epoch 302/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.8517e-05
#
# Epoch 00302: loss did not improve from 0.00006
# Epoch 303/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8146e-05
#
# Epoch 00303: loss did not improve from 0.00006
# Epoch 304/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.6411e-05
#
# Epoch 00304: loss did not improve from 0.00006
# Epoch 305/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.8486e-05
#
# Epoch 00305: loss did not improve from 0.00006
# Epoch 306/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9047e-05
#
# Epoch 00306: loss did not improve from 0.00006
# Epoch 307/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9820e-05
#
# Epoch 00307: loss did not improve from 0.00006
# Epoch 308/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.3021e-05
#
# Epoch 00308: loss did not improve from 0.00006
# Epoch 309/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.8307e-05
#
# Epoch 00309: loss did not improve from 0.00006
# Epoch 310/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.6773e-05
#
# Epoch 00310: loss did not improve from 0.00006
# Epoch 311/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 9.1925e-05
#
# Epoch 00311: loss did not improve from 0.00006
# Epoch 312/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 1.0398e-04
#
# Epoch 00312: loss did not improve from 0.00006
# Epoch 313/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.5267e-05
#
# Epoch 00313: loss did not improve from 0.00006
# Epoch 314/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.0435e-05
#
# Epoch 00314: loss did not improve from 0.00006
# Epoch 315/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9344e-05
#
# Epoch 00315: loss did not improve from 0.00006
# Epoch 316/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.8435e-05
#
# Epoch 00316: loss did not improve from 0.00006
# Epoch 317/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.7905e-05
#
# Epoch 00317: loss did not improve from 0.00006
# Epoch 318/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.9606e-05
#
# Epoch 00318: loss did not improve from 0.00006
# Epoch 319/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 8.2834e-05
#
# Epoch 00319: loss did not improve from 0.00006
# Epoch 320/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.9430e-05
#
# ...
#
# Epoch 00681: loss did not improve from 0.00003
# Epoch 682/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4681e-05
#
# Epoch 00682: loss did not improve from 0.00003
# Epoch 683/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5246e-05
#
# Epoch 00683: loss did not improve from 0.00003
# Epoch 684/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.3856e-05
#
# Epoch 00684: loss did not improve from 0.00003
# Epoch 685/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.3516e-05
#
# Epoch 00685: loss did not improve from 0.00003
# Epoch 686/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.1408e-05
#
# Epoch 00686: loss did not improve from 0.00003
# Epoch 687/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.5594e-05
#
# Epoch 00687: loss did not improve from 0.00003
# Epoch 688/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0833e-05
#
# Epoch 00688: loss did not improve from 0.00003
# Epoch 689/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7419e-05
#
# Epoch 00689: loss did not improve from 0.00003
# Epoch 690/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.6442e-05
#
# Epoch 00690: loss did not improve from 0.00003
# Epoch 691/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0603e-05
#
# Epoch 00691: loss did not improve from 0.00003
# Epoch 692/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.6477e-05
#
# Epoch 00692: loss did not improve from 0.00003
# Epoch 693/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 7.1544e-05
#
# Epoch 00693: loss did not improve from 0.00003
# Epoch 694/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.3840e-05
#
# Epoch 00694: loss did not improve from 0.00003
# Epoch 695/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4710e-05
#
# Epoch 00695: loss did not improve from 0.00003
# Epoch 696/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.0241e-05
#
# Epoch 00696: loss did not improve from 0.00003
# Epoch 697/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4087e-05
#
# Epoch 00697: loss did not improve from 0.00003
# Epoch 698/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7867e-05
#
# Epoch 00698: loss did not improve from 0.00003
# Epoch 699/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0981e-05
#
# Epoch 00699: loss did not improve from 0.00003
# Epoch 700/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7331e-05
#
# Epoch 00700: loss did not improve from 0.00003
# Epoch 701/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0158e-05
#
# Epoch 00701: loss did not improve from 0.00003
# Epoch 702/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.4989e-05
#
# Epoch 00702: loss did not improve from 0.00003
# Epoch 703/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5757e-05
#
# Epoch 00703: loss did not improve from 0.00003
# Epoch 704/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7712e-05
#
# Epoch 00704: loss did not improve from 0.00003
# Epoch 705/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.3857e-05
#
# Epoch 00705: loss did not improve from 0.00003
# Epoch 706/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.1970e-05
#
# Epoch 00706: loss did not improve from 0.00003
# Epoch 707/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5146e-05
#
# Epoch 00707: loss did not improve from 0.00003
# Epoch 708/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7882e-05
#
# Epoch 00708: loss did not improve from 0.00003
# Epoch 709/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0165e-05
#
# Epoch 00709: loss did not improve from 0.00003
# Epoch 710/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2438e-05
#
# Epoch 00710: loss did not improve from 0.00003
# Epoch 711/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7612e-05
#
# Epoch 00711: loss did not improve from 0.00003
# Epoch 712/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7895e-05
#
# Epoch 00712: loss did not improve from 0.00003
# Epoch 713/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.1813e-05
#
# Epoch 00713: loss did not improve from 0.00003
# Epoch 714/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.1585e-05
#
# Epoch 00714: loss did not improve from 0.00003
# Epoch 715/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8434e-05
#
# Epoch 00715: loss did not improve from 0.00003
# Epoch 716/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.6738e-05
#
# Epoch 00716: loss did not improve from 0.00003
# Epoch 717/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7365e-05
#
# Epoch 00717: loss did not improve from 0.00003
# Epoch 718/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.3934e-05
#
# Epoch 00718: loss did not improve from 0.00003
# Epoch 719/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.0833e-05
#
# Epoch 00719: loss did not improve from 0.00003
# Epoch 720/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2607e-05
#
# Epoch 00720: loss did not improve from 0.00003
# Epoch 721/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.1327e-05
#
# Epoch 00721: loss did not improve from 0.00003
# Epoch 722/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4458e-05
#
# Epoch 00722: loss did not improve from 0.00003
# Epoch 723/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.9283e-05
#
# Epoch 00723: loss did not improve from 0.00003
# Epoch 724/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.5751e-05
#
# Epoch 00724: loss did not improve from 0.00003
# Epoch 725/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.6543e-05
#
# Epoch 00725: loss did not improve from 0.00003
# Epoch 726/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.9503e-05
#
# Epoch 00726: loss did not improve from 0.00003
# Epoch 727/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.8570e-05
#
# Epoch 00727: loss did not improve from 0.00003
# Epoch 728/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7454e-05
#
# Epoch 00728: loss did not improve from 0.00003
# Epoch 729/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.8333e-05
#
# Epoch 00729: loss did not improve from 0.00003
# Epoch 730/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.2709e-05
#
# Epoch 00730: loss did not improve from 0.00003
# Epoch 731/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.5946e-05
#
# Epoch 00731: loss did not improve from 0.00003
# Epoch 732/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7759e-05
#
# Epoch 00732: loss did not improve from 0.00003
# Epoch 733/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.5537e-05
#
# Epoch 00733: loss did not improve from 0.00003
# Epoch 734/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.1960e-05
#
# Epoch 00734: loss did not improve from 0.00003
# Epoch 735/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5111e-05
#
# Epoch 00735: loss did not improve from 0.00003
# Epoch 736/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4957e-05
#
# Epoch 00736: loss did not improve from 0.00003
# Epoch 737/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.7415e-05
#
# Epoch 00737: loss did not improve from 0.00003
# Epoch 738/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.9211e-05
#
# Epoch 00738: loss did not improve from 0.00003
# Epoch 739/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8192e-05
#
# Epoch 00739: loss did not improve from 0.00003
# Epoch 740/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2261e-05
#
# Epoch 00740: loss did not improve from 0.00003
# Epoch 741/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2922e-05
#
# Epoch 00741: loss did not improve from 0.00003
# Epoch 742/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.9877e-05
#
# Epoch 00742: loss did not improve from 0.00003
# Epoch 743/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.0518e-05
#
# Epoch 00743: loss did not improve from 0.00003
# Epoch 744/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7990e-05
#
# Epoch 00744: loss did not improve from 0.00003
# Epoch 745/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5693e-05
#
# Epoch 00745: loss did not improve from 0.00003
# Epoch 746/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7323e-05
#
# Epoch 00746: loss did not improve from 0.00003
# Epoch 747/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0353e-05
#
# Epoch 00747: loss did not improve from 0.00003
# Epoch 748/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2175e-05
#
# Epoch 00748: loss did not improve from 0.00003
# Epoch 749/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2794e-05
#
# Epoch 00749: loss did not improve from 0.00003
# Epoch 750/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.9716e-05
#
# Epoch 00750: loss did not improve from 0.00003
# Epoch 751/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0233e-05
#
# Epoch 00751: loss did not improve from 0.00003
# Epoch 752/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8116e-05
#
# Epoch 00752: loss did not improve from 0.00003
# Epoch 753/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7919e-05
#
# Epoch 00753: loss did not improve from 0.00003
# Epoch 754/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8081e-05
#
# Epoch 00754: loss did not improve from 0.00003
# Epoch 755/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.3292e-05
#
# Epoch 00755: loss did not improve from 0.00003
# Epoch 756/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.6631e-05
#
# Epoch 00756: loss did not improve from 0.00003
# Epoch 757/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.6617e-05
#
# Epoch 00757: loss did not improve from 0.00003
# Epoch 758/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.1246e-05
#
# Epoch 00758: loss did not improve from 0.00003
# Epoch 759/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5673e-05
#
# Epoch 00759: loss did not improve from 0.00003
# Epoch 760/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7457e-05
#
# Epoch 00760: loss did not improve from 0.00003
# Epoch 761/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5668e-05
#
# Epoch 00761: loss did not improve from 0.00003
# Epoch 762/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.1999e-05
#
# Epoch 00762: loss did not improve from 0.00003
# Epoch 763/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.2096e-05
#
# Epoch 00763: loss did not improve from 0.00003
# Epoch 764/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.1926e-05
#
# Epoch 00764: loss did not improve from 0.00003
# Epoch 765/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.4461e-05
#
# Epoch 00765: loss did not improve from 0.00003
# Epoch 766/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.2668e-05
#
# Epoch 00766: loss did not improve from 0.00003
# Epoch 767/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7428e-05
#
# Epoch 00767: loss did not improve from 0.00003
# Epoch 768/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.7707e-05
#
# Epoch 00768: loss did not improve from 0.00003
# Epoch 769/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.1298e-05
#
# Epoch 00769: loss did not improve from 0.00003
# Epoch 770/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.0229e-05
#
# Epoch 00770: loss did not improve from 0.00003
# Epoch 771/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.6998e-05
#
# Epoch 00771: loss did not improve from 0.00003
# Epoch 772/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 5.5289e-05
#
# Epoch 00772: loss did not improve from 0.00003
# Epoch 773/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.8537e-05
#
# Epoch 00773: loss did not improve from 0.00003
# Epoch 774/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.5090e-05
#
# Epoch 00774: loss did not improve from 0.00003
# Epoch 775/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.5231e-05
#
# Epoch 00775: loss did not improve from 0.00003
# Epoch 776/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 4.1180e-05
#
# Epoch 00776: loss did not improve from 0.00003
# Epoch 777/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 3.7792e-05
#
# Epoch 00777: loss did not improve from 0.00003
# Epoch 778/100000
# 501/501 [==============================] - 1s 2ms/step - loss: 6.2659e-05
#
# Epoch 00778: loss did not improve from 0.00003
# Epoch 00778: early stopping
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/DL/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/DL/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/DL/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_20223/537342146.py in <module>
#      33 # Graphs
#      34 direction='results/graph'
# ---> 35 graphs(direccion=direction,result=result)
#
# ~/Escritorio/Repositorio_Rodrigo_Gil/src/anomaly_detection/Autoencoder_anomaly_detection.py in graphs(direccion, result)
#     107         for prop in result.columns[1:-1]:
#     108                 fig,ax=plt.subplots(figsize=(20, 16))
# --> 109                 plt.plot(result['index'],result[prop],marker="o",label=prop)
#     110                 plt.plot(result[result['Out/In']==1]['index'],result[result['Out/In']==1][prop],marker="o",color="red",linestyle='')
#     111                 plt.title(prop, fontdict=None, loc='center', pad=None,fontsize=30)
#
# ~/anaconda3/envs/DL/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/anaconda3/envs/DL/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'index'
